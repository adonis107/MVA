# %% [markdown]
# ## Regression Problem: House Prices Prediction
# In this exercise, we will solve a regression problem with a neural network.
#
# **Objective:** The goal is to predict the house selling prices .
#
# **Dataset:**  A csv file with 1460 samples is provided (on the course webpage). Each example contains four input features. We will use 1000 examples as training set, 200 as validation set and the rest as test set.
#    * **Feature names**: OverallQual, YearBuilt, TotalBsmtSF, GrLivArea
#    * **Target**: SalePrice
#
# **NB:** new required libraries: `pandas`, `seaborn`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import seaborn as sns

# %matplotlib inline

# %%
# Load data:
df = pd.read_csv("house_prices.csv")

# %%
df.head(3)
# Out:
#    OverallQual  YearBuilt  TotalBsmtSF  GrLivArea  SalePrice
# 0            7       2003          856       1710     208500
# 1            6       1976         1262       1262     181500
# 2            7       2001          920       1786     223500

# %%
df.info()  # get more information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OverallQual  1460 non-null   int64
#  1   YearBuilt    1460 non-null   int64
#  2   TotalBsmtSF  1460 non-null   int64
#  3   GrLivArea    1460 non-null   int64
#  4   SalePrice    1460 non-null   int64
# dtypes: int64(5)
# memory usage: 57.2 KB

# %% [markdown]
# ### Data Analysis
# Before training, we need first to analyze the dataset, to know its properties better.

# %%
sns.pairplot(
    df,
    x_vars=["OverallQual", "YearBuilt", "TotalBsmtSF", "GrLivArea"],
    y_vars=["SalePrice"],
)

# %% [markdown]
# ### House prices prediction

# %% [markdown]
# Here is a skeleton of a neural network with a single layer (thus: a linear classifier). This is the model you'll start with and improve during this exercise.
#
# Look at the code and run it to see its structure, then follow the questions below to iteratively improve the model.

# %%
X = df[
    ["OverallQual", "YearBuilt", "TotalBsmtSF", "GrLivArea"]
]  # get the four features from the dataframe
y = df["SalePrice"]  # get the target values

# %%
X_train = X.iloc[:1000]
y_train = y.iloc[:1000]

X_val = X.iloc[1000:1200]
y_val = y.iloc[1000:1200]

X_test = X.iloc[1200:]
y_test = y.iloc[1200:]

# %%
# Construct a model with one layer
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        self.l1 = nn.Linear(4, 1)

    def forward(self, inputs):
        outputs = self.l1(inputs)
        return outputs

# %%
# Define hyper-parameters:
model = Model()

# Choose the hyperparameters for training:
num_epochs = 10
batch_size = 10

# Training criterion. This one is a mean squared error (MSE) loss between the output
# of the network and the target label
criterion = nn.MSELoss()

# Use SGD optimizer with a learning rate of 0.01
# It is initialized on our model
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
train_set = TensorDataset(
    torch.from_numpy(np.array(X_train)).float(),
    torch.from_numpy(np.array(y_train)).float(),
)  # creat the dataset.

# %%
def train(num_epochs, batch_size, criterion, optimizer, model, dataset):
    dataloader = DataLoader(dataset, batch_size, shuffle=True)

    model.train()
    for epoch in range(num_epochs):
        epoch_average_loss = 0.0
        for X, y in dataloader:
            y_pre = model(X).view(-1)
            loss = criterion(y_pre, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_average_loss += loss.item() * batch_size / len(train_set)

        if (epoch + 1) % 1 == 0:
            print(
                "Epoch [{}/{}], Loss_error: {:.4f}".format(
                    epoch + 1, num_epochs, epoch_average_loss
                )
            )

# %%
train(num_epochs, batch_size, criterion, optimizer, model, train_set)
# Out:
# Epoch [1/10], Loss_error: nan
# Epoch [2/10], Loss_error: nan
# Epoch [3/10], Loss_error: nan
# Epoch [4/10], Loss_error: nan
# Epoch [5/10], Loss_error: nan
# Epoch [6/10], Loss_error: nan
# Epoch [7/10], Loss_error: nan
# Epoch [8/10], Loss_error: nan
# Epoch [9/10], Loss_error: nan
# Epoch [10/10], Loss_error: nan

# %% [markdown]
# #### Evaluate the Model on the validation set

# %%
# Calculate mean squared error on validation set
model.eval()
with torch.no_grad():
    y_pre_val = model(torch.from_numpy(np.array(X_val)).float()).view(-1)
error = criterion(y_pre_val, torch.tensor(np.array(y_val)).float()).item()
print("The loss on validation set is:", error)
# Out:
# The loss on validation set is: nan

# %% [markdown]
# ### Exercise 1: Impact of the architecture of the model
#
# The class `Model` is the definition of your model. You can now modify it to try out different architectures and
# see the impact of the following factors:
#
# * Try to add more layers (1, 2, 3, more ?)
# * Try different activation functions ([sigmoid](https://pytorch.org/docs/stable/nn.functional.html#torch.nn.functional.sigmoid), [tanh](https://pytorch.org/docs/stable/nn.functional.html#torch.nn.functional.tanh), [relu](https://pytorch.org/docs/stable/nn.functional.html#torch.nn.functional.relu), etc.)
# * Try to change the number of neurons in each layer (5, 10, 20, more ?)

# %%
# Load data:
df = pd.read_csv("house_prices.csv")

X = df[
    ["OverallQual", "YearBuilt", "TotalBsmtSF", "GrLivArea"]
]  # get the four features from the dataframe
y = df["SalePrice"]  # get the target values

X_train = X.iloc[:1000]
y_train = y.iloc[:1000]

X_val = X.iloc[1000:1200]
y_val = y.iloc[1000:1200]

X_test = X.iloc[1200:]
y_test = y.iloc[1200:]

# Adding normalization of the input features using only training set statistics to avoid data leakage
mean = X_train.mean()
std = X_train.std()

X_train = (X_train - mean) / std
X_val = (X_val - mean) / std
X_test = (X_test - mean) / std

# Normalize the target values to get lower loss values
mean_y = y_train.mean()
std_y = y_train.std()
y_train = (y_train - mean_y) / std_y
y_val = (y_val - mean_y) / std_y
y_test = (y_test - mean_y) / std_y

# Create the dataset for training
train_set = TensorDataset(
    torch.from_numpy(np.array(X_train)).float(),
    torch.from_numpy(np.array(y_train)).float(),
)

# %%
class Model(nn.Module):
    def __init__(self, num_layers=3, hidden_size=16, activation="relu", output_size=1):
        super(Model, self).__init__()

        activation_dict = {
            "relu": nn.ReLU(),
            "sigmoid": nn.Sigmoid(),
            "tanh": nn.Tanh(),
            "leaky relu": nn.LeakyReLU(),
        }

        act_layer = activation_dict.get(activation.lower(), nn.ReLU())

        layers = []
        in_features = 4

        for i in range(num_layers):
            layers.append(nn.Linear(in_features, hidden_size))
            layers.append(act_layer)
            in_features = hidden_size

        layers.append(nn.Linear(hidden_size, output_size))

        self.network = nn.Sequential(*layers)

    def forward(self, inputs):
        return self.network(inputs)

# %% [markdown]
# ### Exercise 2: Impact of the optimizer
#
# Retrain the model with different parameters of the optimizer; you can change then in the cell initializing the optimizer, after the definition of your model.
#
# * Use different batch sizes, from 10 to 400 e.g.
# * Try different values of the learning rate (between 0.001 and 10), and see how they impact the training process. Do all network architectures react the same way to different learning rates?
# * Change the duration of the training by increasing the number of epochs
# * Try other optimizers, such as [Adam](https://pytorch.org/docs/stable/optim.html?highlight=adam#torch.optim.Adam) or [RMSprop](https://pytorch.org/docs/stable/optim.html?highlight=rmsprop#torch.optim.RMSprop)
#
# **Note:** These changes may interact with your previous choices of architectures, and you may need to change them as well!

# %%
model = Model(num_layers=3, hidden_size=16, activation="relu", output_size=1)

num_epochs = 100
batch_size = 16
learning_rate = 0.001

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
import time


def train(num_epochs, batch_size, criterion, optimizer, model, dataset):
    start_time = time.time()
    dataloader = DataLoader(dataset, batch_size, shuffle=True)

    model.train()
    for epoch in range(num_epochs):
        epoch_average_loss = 0.0
        for X, y in dataloader:
            y_pre = model(X).view(-1)
            loss = criterion(y_pre, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_average_loss += loss.item() * batch_size / len(train_set)

        if (epoch + 1) % 1 == 0:
            print(
                "Epoch [{}/{}], Loss_error: {:.4f}".format(
                    epoch + 1, num_epochs, epoch_average_loss
                )
            )
    end_time = time.time()
    print(f"Training completed in {end_time - start_time:.2f} seconds")

# %%
train(num_epochs, batch_size, criterion, optimizer, model, train_set)

model.eval()
with torch.no_grad():
    y_pre_val = model(torch.from_numpy(np.array(X_val)).float()).view(-1)
error = criterion(y_pre_val, torch.tensor(np.array(y_val)).float()).item()
print("The loss on validation set is:", error)
# Out:
# Epoch [1/100], Loss_error: 0.8320
# Epoch [2/100], Loss_error: 0.3465
# Epoch [3/100], Loss_error: 0.1905
# Epoch [4/100], Loss_error: 0.1883
# Epoch [5/100], Loss_error: 0.1748
# Epoch [6/100], Loss_error: 0.1768
# Epoch [7/100], Loss_error: 0.1729
# Epoch [8/100], Loss_error: 0.1688
# Epoch [9/100], Loss_error: 0.1657
# Epoch [10/100], Loss_error: 0.1699
# Epoch [11/100], Loss_error: 0.1680
# Epoch [12/100], Loss_error: 0.1665
# Epoch [13/100], Loss_error: 0.1654
# Epoch [14/100], Loss_error: 0.1624
# Epoch [15/100], Loss_error: 0.1652
# Epoch [16/100], Loss_error: 0.1670
# Epoch [17/100], Loss_error: 0.1644
# Epoch [18/100], Loss_error: 0.1605
# Epoch [19/100], Loss_error: 0.1617
# Epoch [20/100], Loss_error: 0.1656
# Epoch [21/100], Loss_error: 0.1618
# Epoch [22/100], Loss_error: 0.1614
# Epoch [23/100], Loss_error: 0.1591
# Epoch [24/100], Loss_error: 0.1552
# Epoch [25/100], Loss_error: 0.1596
# Epoch [26/100], Loss_error: 0.1590
# Epoch [27/100], Loss_error: 0.1542
# Epoch [28/100], Loss_error: 0.1575
# Epoch [29/100], Loss_error: 0.1573
# Epoch [30/100], Loss_error: 0.1575
# Epoch [31/100], Loss_error: 0.1570
# Epoch [32/100], Loss_error: 0.1532
# Epoch [33/100], Loss_error: 0.1591
# Epoch [34/100], Loss_error: 0.1602
# Epoch [35/100], Loss_error: 0.1545
# Epoch [36/100], Loss_error: 0.1588
# Epoch [37/100], Loss_error: 0.1547
# Epoch [38/100], Loss_error: 0.1546
# Epoch [39/100], Loss_error: 0.1557
# Epoch [40/100], Loss_error: 0.1536
# Epoch [41/100], Loss_error: 0.1514
# Epoch [42/100], Loss_error: 0.1520
# Epoch [43/100], Loss_error: 0.1552
# Epoch [44/100], Loss_error: 0.1496
# Epoch [45/100], Loss_error: 0.1520
# Epoch [46/100], Loss_error: 0.1525
# Epoch [47/100], Loss_error: 0.1517
# Epoch [48/100], Loss_error: 0.1483
# Epoch [49/100], Loss_error: 0.1480
# Epoch [50/100], Loss_error: 0.1533
# Epoch [51/100], Loss_error: 0.1463
# Epoch [52/100], Loss_error: 0.1475
# Epoch [53/100], Loss_error: 0.1478
# Epoch [54/100], Loss_error: 0.1492
# Epoch [55/100], Loss_error: 0.1467
# Epoch [56/100], Loss_error: 0.1456
# Epoch [57/100], Loss_error: 0.1476
# Epoch [58/100], Loss_error: 0.1542
# Epoch [59/100], Loss_error: 0.1440
# Epoch [60/100], Loss_error: 0.1430
# Epoch [61/100], Loss_error: 0.1437
# Epoch [62/100], Loss_error: 0.1439
# Epoch [63/100], Loss_error: 0.1429
# Epoch [64/100], Loss_error: 0.1447
# Epoch [65/100], Loss_error: 0.1445
# Epoch [66/100], Loss_error: 0.1406
# Epoch [67/100], Loss_error: 0.1437
# Epoch [68/100], Loss_error: 0.1436
# Epoch [69/100], Loss_error: 0.1395
# Epoch [70/100], Loss_error: 0.1401
# Epoch [71/100], Loss_error: 0.1405
# Epoch [72/100], Loss_error: 0.1462
# Epoch [73/100], Loss_error: 0.1410
# Epoch [74/100], Loss_error: 0.1411
# Epoch [75/100], Loss_error: 0.1394
# Epoch [76/100], Loss_error: 0.1390
# Epoch [77/100], Loss_error: 0.1407
# Epoch [78/100], Loss_error: 0.1375
# Epoch [79/100], Loss_error: 0.1411
# Epoch [80/100], Loss_error: 0.1438
# Epoch [81/100], Loss_error: 0.1379
# Epoch [82/100], Loss_error: 0.1383
# Epoch [83/100], Loss_error: 0.1354
# Epoch [84/100], Loss_error: 0.1378
# Epoch [85/100], Loss_error: 0.1392
# Epoch [86/100], Loss_error: 0.1418
# Epoch [87/100], Loss_error: 0.1388
# Epoch [88/100], Loss_error: 0.1383
# Epoch [89/100], Loss_error: 0.1349
# Epoch [90/100], Loss_error: 0.1348
# Epoch [91/100], Loss_error: 0.1346
# Epoch [92/100], Loss_error: 0.1353
# Epoch [93/100], Loss_error: 0.1379
# Epoch [94/100], Loss_error: 0.1383
# Epoch [95/100], Loss_error: 0.1340
# Epoch [96/100], Loss_error: 0.1323
# Epoch [97/100], Loss_error: 0.1400
# Epoch [98/100], Loss_error: 0.1345
# Epoch [99/100], Loss_error: 0.1329
# Epoch [100/100], Loss_error: 0.1348
# Training completed in 1.46 seconds
# The loss on validation set is: 0.14761577546596527

# %% [markdown]
# ### Exercise 3: Impact of the loss function
# As mensioned before in the first problem (binary classification), one can minimize the negative of log-likelihood of the probability for all samples $x$: $$ \sum_{(x,y) \,\in\, \text{Dataset}} - \log p(y | x) $$ If we define $p(y_i | x_i) = \frac{1}{\sqrt{2\pi}}e^{-\frac{(y_i - f(x_i))^2}{2}}$, then the loss function becomes the mean squared error.
#
# There is another loss function worth to try: the Gaussian likelihood loss function.
# Rather than predicting a single value $y$ given $x$, we predict a probability distribution over possible answers, which helps dealing with ambiguous cases and expressing uncertainty. To do this, for each possible input $x$, the network will output the parameters of the distribution modeling $p(y|x)$. For instance in our case, we choose to model output distributions with Gaussian distributions $\mathcal{N}(\mu, \sigma)$, which are parameterized by their mean $\mu$ and their standard deviation $\sigma$. Therefore for each input $x$ we have to output two quantities: $\mu(x)$ and $\sigma(x)$. The probability becomes: $$p(y_i | x_i) = \frac{1}{\sqrt{2\pi \sigma(x_i)^2}}e^{-\frac{(y_i - \mu(x_i))^2}{2\sigma(x_i)^2}}$$ Then the loss function becomes: $$L =\sum\limits_{i=1}^{N}  \frac{1}{2} \log ( 2\pi\sigma_i^{2} ) + \frac{1}{2\sigma_i^{2}}  (y_{i} - \mu_i)^{2}$$ If we set $\sigma=1$, we obtain MSE the loss function.
#
# * Try to replace the loss function with this one, and compare the differences between the two losses.
#
# * **Hints**:
#     * You need two outputs of your network, one represents the $\mu(x_i)$, another for $\log( \sigma(x_i)^2 )$ (better for optimization)
#     * Try deeper models, or you will not predict the variance $\sigma$ well.

# %%
model_gauss = Model(output_size=2)

num_epochs = 100
batch_size = 32
learning_rate = 0.001

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def gaussian_likelihood_loss(output, target):
    """
    output: (batch_size, 2) containing [mu, log_var]
    target: (batch_size) containing [y]
    """
    mu = output[:, 0]
    log_var = output[:, 1]

    target = target.view_as(mu)
    var = torch.exp(log_var)
    log_2pi = np.log(2 * np.pi)

    loss = 0.5 * (log_2pi + log_var) + (target - mu) ** 2 / (2 * var)
    return loss.mean()


def train_gaussian(num_epochs, batch_size, optimizer, model, dataset):
    start_time = time.time()
    dataloader = DataLoader(dataset, batch_size, shuffle=True)
    len_train_set = len(dataset)

    model.train()
    for epoch in range(num_epochs):
        epoch_average_loss = 0.0

        for X, y in dataloader:
            # Forward pass
            outputs = model(X)

            # Compute Gaussian likelihood loss
            loss = gaussian_likelihood_loss(outputs, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Accumulate loss
            epoch_average_loss += loss.item() * batch_size / len_train_set

        if (epoch + 1) % 1 == 0:
            print(
                "Epoch [{}/{}], Gaussian Loss: {:.4f}".format(
                    epoch + 1, num_epochs, epoch_average_loss
                )
            )

    end_time = time.time()
    print(f"Training completed in {end_time - start_time:.2f} seconds")

# %%
train_gaussian(num_epochs, batch_size, optimizer, model_gauss, train_set)

model_gauss.eval()
with torch.no_grad():
    X_val_tensor = torch.from_numpy(np.array(X_val)).float()
    y_val_tensor = torch.from_numpy(np.array(y_val)).float()

    outputs = model_gauss(X_val_tensor)

    val_loss = gaussian_likelihood_loss(outputs, y_val_tensor)
    print("The Gaussian loss on validation set is:", val_loss.item())

    # Compute MSE to compare with the previous models
    predicted_means = outputs[:, 0]
    mse_criterion = nn.MSELoss()
    val_mse = mse_criterion(predicted_means, y_val_tensor)
    print("The MSE loss on validation set is: ", val_mse.item())
# Out:
# Epoch [1/100], Gaussian Loss: 1.4914
# Epoch [2/100], Gaussian Loss: 1.4907
# Epoch [3/100], Gaussian Loss: 1.5087
# Epoch [4/100], Gaussian Loss: 1.5160
# Epoch [5/100], Gaussian Loss: 1.5025
# Epoch [6/100], Gaussian Loss: 1.5007
# Epoch [7/100], Gaussian Loss: 1.4910
# Epoch [8/100], Gaussian Loss: 1.4900
# Epoch [9/100], Gaussian Loss: 1.5464
# Epoch [10/100], Gaussian Loss: 1.4936
# Epoch [11/100], Gaussian Loss: 1.4978
# Epoch [12/100], Gaussian Loss: 1.4910
# Epoch [13/100], Gaussian Loss: 1.4963
# Epoch [14/100], Gaussian Loss: 1.4880
# Epoch [15/100], Gaussian Loss: 1.4883
# Epoch [16/100], Gaussian Loss: 1.4968
# Epoch [17/100], Gaussian Loss: 1.4911
# Epoch [18/100], Gaussian Loss: 1.4926
# Epoch [19/100], Gaussian Loss: 1.4899
# Epoch [20/100], Gaussian Loss: 1.5020
# Epoch [21/100], Gaussian Loss: 1.4887
# Epoch [22/100], Gaussian Loss: 1.4956
# Epoch [23/100], Gaussian Loss: 1.4893
# Epoch [24/100], Gaussian Loss: 1.5079
# Epoch [25/100], Gaussian Loss: 1.4905
# Epoch [26/100], Gaussian Loss: 1.5104
# Epoch [27/100], Gaussian Loss: 1.4914
# Epoch [28/100], Gaussian Loss: 1.4962
# Epoch [29/100], Gaussian Loss: 1.4942
# Epoch [30/100], Gaussian Loss: 1.5015
# Epoch [31/100], Gaussian Loss: 1.4918
# Epoch [32/100], Gaussian Loss: 1.4899
# Epoch [33/100], Gaussian Loss: 1.4900
# Epoch [34/100], Gaussian Loss: 1.4925
# Epoch [35/100], Gaussian Loss: 1.4858
# Epoch [36/100], Gaussian Loss: 1.4993
# Epoch [37/100], Gaussian Loss: 1.4940
# Epoch [38/100], Gaussian Loss: 1.4982
# Epoch [39/100], Gaussian Loss: 1.5054
# Epoch [40/100], Gaussian Loss: 1.4890
# Epoch [41/100], Gaussian Loss: 1.5035
# Epoch [42/100], Gaussian Loss: 1.5262
# Epoch [43/100], Gaussian Loss: 1.4975
# Epoch [44/100], Gaussian Loss: 1.5069
# Epoch [45/100], Gaussian Loss: 1.5022
# Epoch [46/100], Gaussian Loss: 1.4901
# Epoch [47/100], Gaussian Loss: 1.4946
# Epoch [48/100], Gaussian Loss: 1.5060
# Epoch [49/100], Gaussian Loss: 1.4868
# Epoch [50/100], Gaussian Loss: 1.4975
# Epoch [51/100], Gaussian Loss: 1.4942
# Epoch [52/100], Gaussian Loss: 1.4909
# Epoch [53/100], Gaussian Loss: 1.4943
# Epoch [54/100], Gaussian Loss: 1.4884
# Epoch [55/100], Gaussian Loss: 1.5000
# Epoch [56/100], Gaussian Loss: 1.4959
# Epoch [57/100], Gaussian Loss: 1.5001
# Epoch [58/100], Gaussian Loss: 1.4890
# Epoch [59/100], Gaussian Loss: 1.5011
# Epoch [60/100], Gaussian Loss: 1.4897
# Epoch [61/100], Gaussian Loss: 1.4926
# Epoch [62/100], Gaussian Loss: 1.4868
# Epoch [63/100], Gaussian Loss: 1.4949
# Epoch [64/100], Gaussian Loss: 1.5060
# Epoch [65/100], Gaussian Loss: 1.4903
# Epoch [66/100], Gaussian Loss: 1.4895
# Epoch [67/100], Gaussian Loss: 1.4883
# Epoch [68/100], Gaussian Loss: 1.5424
# Epoch [69/100], Gaussian Loss: 1.4888
# Epoch [70/100], Gaussian Loss: 1.4876
# Epoch [71/100], Gaussian Loss: 1.4894
# Epoch [72/100], Gaussian Loss: 1.4872
# Epoch [73/100], Gaussian Loss: 1.4908
# Epoch [74/100], Gaussian Loss: 1.4927
# Epoch [75/100], Gaussian Loss: 1.5018
# Epoch [76/100], Gaussian Loss: 1.4886
# Epoch [77/100], Gaussian Loss: 1.5145
# Epoch [78/100], Gaussian Loss: 1.4956
# Epoch [79/100], Gaussian Loss: 1.4926
# Epoch [80/100], Gaussian Loss: 1.4989
# Epoch [81/100], Gaussian Loss: 1.4861
# Epoch [82/100], Gaussian Loss: 1.4851
# Epoch [83/100], Gaussian Loss: 1.5006
# Epoch [84/100], Gaussian Loss: 1.4844
# Epoch [85/100], Gaussian Loss: 1.4998
# Epoch [86/100], Gaussian Loss: 1.5022
# Epoch [87/100], Gaussian Loss: 1.4887
# Epoch [88/100], Gaussian Loss: 1.4896
# Epoch [89/100], Gaussian Loss: 1.5237
# Epoch [90/100], Gaussian Loss: 1.5021
# Epoch [91/100], Gaussian Loss: 1.4915
# Epoch [92/100], Gaussian Loss: 1.4972
# Epoch [93/100], Gaussian Loss: 1.5019
# Epoch [94/100], Gaussian Loss: 1.4917
# Epoch [95/100], Gaussian Loss: 1.4940
# Epoch [96/100], Gaussian Loss: 1.4946
# Epoch [97/100], Gaussian Loss: 1.4902
# Epoch [98/100], Gaussian Loss: 1.4976
# Epoch [99/100], Gaussian Loss: 1.5034
# Epoch [100/100], Gaussian Loss: 1.4964
# Training completed in 0.81 seconds
# The Gaussian loss on validation set is: 1.5418325662612915
# The MSE loss on validation set is:  1.1855148077011108

# %% [markdown]
# ### Exercice 4: Prediction on test set
#
# * Once you have a model that seems satisfying on the validation dataset, you SHOULD evaluate it on a test dataset that has never been used before, to obtain a final accuracy value.
# * When using the Gaussian likelihood function, the confidence of the network in its prediction is reflected in the variance it outputs. It can be interesting to check how this uncertainty varies with the data. For example, the uncertainty will decrease when the feature `OverallQual` increases. Plot the variance $\sigma(x)$ w.r.t one of the three features, on test set, and describe what you observe.

# %%
# IF TRAINED WITH MSE LOSS

model.eval()
with torch.no_grad():
    y_pred_test = model(torch.from_numpy(np.array(X_test)).float())
    if isinstance(y_pred_test, tuple):  # Gaussian model
        y_pred_test = y_pred_test[0]
    y_pred_test = y_pred_test.view(-1)

test_loss = nn.MSELoss()(y_pred_test, torch.from_numpy(np.array(y_test)).float())

print("Test MSE:", test_loss.item())
# Out:
# Test MSE: 0.18519073724746704

# %%
# IF TRAINED WITH GAUSSIAN LIKELIHOOD LOSS

model_gauss.eval()
with torch.no_grad():
    X_test_tensor = torch.from_numpy(np.array(X_test)).float()
    y_test_tensor = torch.from_numpy(np.array(y_test)).float()

    outputs = model_gauss(X_test_tensor)

    test_loss = gaussian_likelihood_loss(outputs, y_test_tensor)
    print("The Gaussian loss on test set is:", test_loss.item())

    # Compute MSE to compare with the previous models
    predicted_means = outputs[:, 0]
    mse_criterion = nn.MSELoss()
    test_mse = mse_criterion(predicted_means, y_test_tensor)
    print("The MSE loss on test set is: ", test_mse.item())
# Out:
# The Gaussian loss on test set is: 1.34751558303833
# The MSE loss on test set is:  0.865089476108551
